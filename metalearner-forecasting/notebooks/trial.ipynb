# %%
import numpy as np

# Generate example dataset
np.random.seed(0)
dataset = np.random.rand(100, 3)  # 100 rows, 3 columns

# %%
dataset
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338],
#        [0.54488318, 0.4236548 , 0.64589411],
#        [0.43758721, 0.891773  , 0.96366276],
#        [0.38344152, 0.79172504, 0.52889492],
#        [0.56804456, 0.92559664, 0.07103606],
#        [0.0871293 , 0.0202184 , 0.83261985],
#        [0.77815675, 0.87001215, 0.97861834],
#        [0.79915856, 0.46147936, 0.78052918],
#        [0.11827443, 0.63992102, 0.14335329],
#        [0.94466892, 0.52184832, 0.41466194],
#        [0.26455561, 0.77423369, 0.45615033],
#        [0.56843395, 0.0187898 , 0.6176355 ],
#        [0.61209572, 0.616934  , 0.94374808],
#        [0.6818203 , 0.3595079 , 0.43703195],
#        [0.6976312 , 0.06022547, 0.66676672],
#        [0.67063787, 0.21038256, 0.1289263 ],
#        [0.31542835, 0.36371077, 0.57019677],
#        [0.43860151, 0.98837384, 0.10204481],
#        [0.20887676, 0.16130952, 0.65310833],
#        [0.2532916 , 0.46631077, 0.24442559],
#        [0.15896958, 0.11037514, 0.65632959],
# ...

# %%
# Exclude the first column (target column) from the dataset
one = dataset[:, :, 1:].copy()

# Convert to input_1
input_1 = []
for i in range(one.shape[0]):
    input_1.append(one[i])
input_1 = np.array(input_1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Crider_Forecasting\crider_forecasting\notebooks\trial.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/d%3A/Crider_Forecasting/crider_forecasting/notebooks/trial.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Exclude the first column (target column) from the dataset
# ----> <a href='vscode-notebook-cell:/d%3A/Crider_Forecasting/crider_forecasting/notebooks/trial.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> one = dataset[:, :, 1:].copy()
#       <a href='vscode-notebook-cell:/d%3A/Crider_Forecasting/crider_forecasting/notebooks/trial.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> # Convert to input_1
#       <a href='vscode-notebook-cell:/d%3A/Crider_Forecasting/crider_forecasting/notebooks/trial.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> input_1 = []
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
